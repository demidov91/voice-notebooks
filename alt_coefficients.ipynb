# %%
import pandas as pd
import numpy as np
from decimal import Decimal

# %%
df = pd.read_csv('trusted-for-alternative-fixed.csv', converters={'latitude': Decimal, 'longitude': Decimal})

# Too many for against, one observer, high turnout.
df = df[~df['id'].isin(['04-114-0017'])]

# %%
areas = ['city', 'minsk_suburb', 'capital', 'village', 'town_below100', 'town_over100', 'embassy']

candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja', 'tihanovkaja']
alt_candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja']
alt_candidates_no_corrupted = set(alt_candidates) - {'corrupted'}

# %%
def official_alt_candidates(data):
    return _generic_candidates_sum(data, 'officialVotes', alt_candidates)

def _generic_candidates_sum(data, source, candidates_to_sum):
    return sum([data[f'{candidate}_{source}'] for candidate in candidates_to_sum])

# %%
alt_candidates_coefficients = []

for candidate in set(alt_candidates) - {'against', 'corrupted'}:
    for area in areas:
        data = df[df['area'] == area]
        values = data[f'{candidate}_officialVotes'] / official_alt_candidates(data)
        coeff = np.mean(values)
        std = np.std(values)
        alt_candidates_coefficients.append({
            'candidate': candidate,
            'area': area,
            'coefficient': coeff,
            'std': std,
            'coeff_variation': std / coeff,
        })
    values = df[f'{candidate}_officialVotes'] / official_alt_candidates(df)
    coeff = np.mean(values)
    std = np.std(values)
    alt_candidates_coefficients.append({
        'candidate': candidate,
        'area': 'total',
        'coefficient': coeff,
        'std': std,
        'coeff_variation': std / coeff,
    })
    
        
for area in areas:
    data = df[df['area'] == area]
    values = (data[f'against_officialVotes'] + data['corrupted_officialVotes']) / official_alt_candidates(data)
    coeff = np.mean(values)
    std = np.std(values)
    alt_candidates_coefficients.append({
        'candidate': 'against+corrupted',
        'area': area,
        'coefficient': coeff,
        'std': std,
        'coeff_variation': std / coeff,
    })
    
values = (df[f'against_officialVotes'] + df['corrupted_officialVotes']) / official_alt_candidates(df)
coeff = np.mean(values)
std = np.std(values)
alt_candidates_coefficients.append({
    'candidate': 'against+corrupted',
    'area': 'total',
    'coefficient': coeff,
    'std': std,
    'coeff_variation': std / coeff,
})


with_corrupted_mask = df['corrupted_officialVotes'] > 0

for area in areas:
    data = df[(df['area'] == area) & with_corrupted_mask]
    values = data['corrupted_officialVotes'] / (data['against_officialVotes'] + data['corrupted_officialVotes'])
    coeff = np.mean(values)
    std = np.std(values)
    alt_candidates_coefficients.append({
        'candidate': 'corrupted/corrupted+against',
        'area': area,
        'coefficient': coeff,
        'std': std,
        'coeff_variation': std / coeff,
    })
    
data = df[with_corrupted_mask]
    
values = data['corrupted_officialVotes'] / (df[f'against_officialVotes'] + df['corrupted_officialVotes'])
coeff = np.mean(values)
std = np.std(values)
alt_candidates_coefficients.append({
    'candidate': 'corrupted/corrupted+against',
    'area': 'total',
    'coefficient': coeff,
    'std': std,
    'coeff_variation': std / coeff,
})

# %%
alt_coeff_intermediate = pd.DataFrame(alt_candidates_coefficients)

# %%
alt_coeff_intermediate
# Out:
#                       candidate           area  coefficient       std  \
# 0                     dmitriyev           city     0.163334  0.045857
# 1                     dmitriyev   minsk_suburb     0.183484  0.076620
# 2                     dmitriyev        capital     0.125270  0.045466
# 3                     dmitriyev        village     0.164043  0.058193
# 4                     dmitriyev  town_below100     0.166679  0.065230
# 5                     dmitriyev   town_over100     0.160555  0.055606
# 6                     dmitriyev        embassy     0.180056  0.078361
# 7                     dmitriyev          total     0.161440  0.061745
# 8                  kanopatskaja           city     0.108617  0.062587
# 9                  kanopatskaja   minsk_suburb     0.127564  0.044820
# 10                 kanopatskaja        capital     0.120109  0.050866
# 11                 kanopatskaja        village     0.154555  0.073873
# 12                 kanopatskaja  town_below100     0.103094  0.045872
# 13                 kanopatskaja   town_over100     0.110141  0.056742
# 14                 kanopatskaja        embassy     0.166061  0.077868
# 15                 kanopatskaja          total     0.122428  0.061656
# 16                    cherechen           city     0.158694  0.050360
# 17                    cherechen   minsk_suburb     0.118463  0.051467
# 18                    cherechen        capital     0.118768  0.048568
# 19                    cherechen        village     0.122968  0.055708
# 20                    cherechen  town_below100     0.146031  0.055979
# 21                    cherechen   town_over100     0.154384  0.064097
# 22                    cherechen        embassy     0.095024  0.048109
# 23                    cherechen          total     0.135696  0.057246
# 24            against+corrupted           city     0.569356  0.106958
# 25            against+corrupted   minsk_suburb     0.570489  0.109977
# 26            against+corrupted        capital     0.635853  0.099590
# 27            against+corrupted        village     0.558434  0.122142
# 28            against+corrupted  town_below100     0.584196  0.115972
# 29            against+corrupted   town_over100     0.574920  0.127148
# 30            against+corrupted        embassy     0.558859  0.182619
# 31            against+corrupted          total     0.580436  0.119962
# 32  corrupted/corrupted+against           city     0.140506  0.096379
# 33  corrupted/corrupted+against   minsk_suburb     0.169115  0.125777
# 34  corrupted/corrupted+against        capital     0.183926  0.137754
# 35  corrupted/corrupted+against        village     0.185381  0.098777
# 36  corrupted/corrupted+against  town_below100     0.147743  0.092138
# 37  corrupted/corrupted+against   town_over100     0.149536  0.130455
# 38  corrupted/corrupted+against        embassy     0.423748  0.280641
# 39  corrupted/corrupted+against          total     0.174710  0.137419
#
#     coeff_variation
# 0          0.280757
# 1          0.417584
# 2          0.362949
# 3          0.354741
# 4          0.391349
# 5          0.346336
# 6          0.435202
# 7          0.382467
# 8          0.576223
# 9          0.351356
# 10         0.423496
# 11         0.477971
# 12         0.444950
# 13         0.515179
# 14         0.468913
# 15         0.503612
# 16         0.317338
# 17         0.434458
# 18         0.408929
# 19         0.453026
# 20         0.383334
# 21         0.415183
# 22         0.506286
# 23         0.421871
# 24         0.187859
# 25         0.192777
# 26         0.156624
# 27         0.218722
# 28         0.198516
# 29         0.221157
# 30         0.326771
# 31         0.206676
# 32         0.685942
# 33         0.743734
# 34         0.748963
# 35         0.532833
# 36         0.623640
# 37         0.872399
# 38         0.662283
# 39         0.786554

# %%
alt_coeff_final = alt_coeff_intermediate[alt_coeff_intermediate['area'] != 'total'][['candidate', 'area', 'coefficient', 'std', 'coeff_variation']].copy()
alt_coeff_final['source'] = ['area'] * len(alt_coeff_final)

# %%
totals = alt_coeff_intermediate[alt_coeff_intermediate['area'] == 'total']

for c in set(alt_coeff_final['candidate']):
    total_row = totals[totals['candidate'] == c].iloc[0]
    
    mask = (alt_coeff_final['candidate'] == c) & (alt_coeff_final['coeff_variation'] > total_row['coeff_variation'])
    
    for col in ['coefficient', 'std', 'coeff_variation']:
        alt_coeff_final.loc[mask, col] = total_row[col]
        
    alt_coeff_final.loc[mask, 'source'] = 'total'

# %%
alt_coeff_final
# Out:
#                       candidate           area  coefficient       std  \
# 0                     dmitriyev           city     0.163334  0.045857
# 1                     dmitriyev   minsk_suburb     0.161440  0.061745
# 2                     dmitriyev        capital     0.125270  0.045466
# 3                     dmitriyev        village     0.164043  0.058193
# 4                     dmitriyev  town_below100     0.161440  0.061745
# 5                     dmitriyev   town_over100     0.160555  0.055606
# 6                     dmitriyev        embassy     0.161440  0.061745
# 8                  kanopatskaja           city     0.122428  0.061656
# 9                  kanopatskaja   minsk_suburb     0.127564  0.044820
# 10                 kanopatskaja        capital     0.120109  0.050866
# 11                 kanopatskaja        village     0.154555  0.073873
# 12                 kanopatskaja  town_below100     0.103094  0.045872
# 13                 kanopatskaja   town_over100     0.122428  0.061656
# 14                 kanopatskaja        embassy     0.166061  0.077868
# 16                    cherechen           city     0.158694  0.050360
# 17                    cherechen   minsk_suburb     0.135696  0.057246
# 18                    cherechen        capital     0.118768  0.048568
# 19                    cherechen        village     0.135696  0.057246
# 20                    cherechen  town_below100     0.146031  0.055979
# 21                    cherechen   town_over100     0.154384  0.064097
# 22                    cherechen        embassy     0.135696  0.057246
# 24            against+corrupted           city     0.569356  0.106958
# 25            against+corrupted   minsk_suburb     0.570489  0.109977
# 26            against+corrupted        capital     0.635853  0.099590
# 27            against+corrupted        village     0.580436  0.119962
# 28            against+corrupted  town_below100     0.584196  0.115972
# 29            against+corrupted   town_over100     0.580436  0.119962
# 30            against+corrupted        embassy     0.580436  0.119962
# 32  corrupted/corrupted+against           city     0.140506  0.096379
# 33  corrupted/corrupted+against   minsk_suburb     0.169115  0.125777
# 34  corrupted/corrupted+against        capital     0.183926  0.137754
# 35  corrupted/corrupted+against        village     0.185381  0.098777
# 36  corrupted/corrupted+against  town_below100     0.147743  0.092138
# 37  corrupted/corrupted+against   town_over100     0.174710  0.137419
# 38  corrupted/corrupted+against        embassy     0.423748  0.280641
#
#     coeff_variation source
# 0          0.280757   area
# 1          0.382467  total
# 2          0.362949   area
# 3          0.354741   area
# 4          0.382467  total
# 5          0.346336   area
# 6          0.382467  total
# 8          0.503612  total
# 9          0.351356   area
# 10         0.423496   area
# 11         0.477971   area
# 12         0.444950   area
# 13         0.503612  total
# 14         0.468913   area
# 16         0.317338   area
# 17         0.421871  total
# 18         0.408929   area
# 19         0.421871  total
# 20         0.383334   area
# 21         0.415183   area
# 22         0.421871  total
# 24         0.187859   area
# 25         0.192777   area
# 26         0.156624   area
# 27         0.206676  total
# 28         0.198516   area
# 29         0.206676  total
# 30         0.206676  total
# 32         0.685942   area
# 33         0.743734   area
# 34         0.748963   area
# 35         0.532833   area
# 36         0.623640   area
# 37         0.786554  total
# 38         0.662283   area

# %%
for area in areas:
    mask = (alt_coeff_final['area'] == area) & (alt_coeff_final['candidate'] != 'corrupted/corrupted+against')
    k = 1 / alt_coeff_final[mask]['coefficient'].sum()
    print(k)
    alt_coeff_final.loc[mask, 'coefficient'] *= k
    alt_coeff_final.loc[mask, 'std'] *= k
# Out:
# 0.9863765451092582
# 1.0048346008235145
# 1.0
# 0.96643576402378
# 1.0052668875706032
# 0.982508483426381
# 0.9581914245920473

# %%
pure_coeffs = []


corrupted = (
    np.array(alt_coeff_final[alt_coeff_final['candidate'] == 'against+corrupted']['coefficient']) * 
    np.array(alt_coeff_final[alt_coeff_final['candidate'] == 'corrupted/corrupted+against']['coefficient'])
)

against = np.array(alt_coeff_final[alt_coeff_final['candidate'] == 'against+corrupted']['coefficient']) - corrupted

(corrupted, against)
# Out:
# (array([0.0789082 , 0.09694481, 0.11694988, 0.10399012, 0.08676536,
#         0.0996339 , 0.23567529]),
#  array([0.48269116, 0.47630218, 0.51890337, 0.4569637 , 0.50050798,
#         0.4706491 , 0.32049323]))

# %%
alt_coeff_extended = pd.concat([alt_coeff_final, pd.DataFrame([
    {
        'area': area,
        'coefficient': cor,
        'candidate': 'corrupted',
    }
    for area, cor in zip(areas, corrupted)
] + [
    {
        'area': area,
        'coefficient': ag,
        'candidate': 'against',
    }
    for area, ag in zip(areas, against)
])])

# %%
alt_coeff_extended.to_csv('alt_candidates_coefficients.csv', float_format='%.3f', index=False)

# %%
for area in areas:
    mask = (alt_coeff_extended['area'] == area) & (alt_coeff_extended['candidate'].isin(alt_candidates))
    print(sum(alt_coeff_extended[mask]['coefficient']))
# Out:
# 1.0
# 0.9999999999999998
# 1.0
# 0.9999999999999998
# 1.0
# 0.9999999999999999
# 0.9999999999999999
