# %%
from decimal import Decimal
import pandas as pd

# %%
df = pd.read_csv('trusted-for-alternative.csv', converters={'latitude': Decimal, 'longitude': Decimal})

# %%
candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja', 'tihanovkaja']
alt_candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja']

# %%
df.loc[df['corrupted_officialVotes'].isna(), 'corrupted_officialVotes'] = 0

# %%
df.loc[df['id'] == '07-001-0089', 'officialVotes'] -= 42
df.loc[df['id'] == '07-006-0041', 'corrupted_officialVotes'] -= 60

# %%
diff = df['officialVotes'] - sum(df[f'{c}_officialVotes'] for c in (candidates + ['lukashenko']))

# %%
df[diff != 0]
# Out:
#               id           town           area   latitude  longitude  region  \
# 8    01-010-0015          Brest           city  52.086145  23.699866       1
# 29   01-011-0049          Brest           city  52.100105  23.784281       1
# 33   01-011-0079          Brest           city  52.067807  23.729286       1
# 34   01-011-0087          Brest           city   52.05665  23.737146       1
# 71   02-016-0056        Vítebsk           city  55.159012   30.20913       2
# 78   02-071-0015      Домжерицы        village  54.747319   28.31541       2
# 113  03-091-0018        Zhlobin  town_below100  52.905065  30.014088       3
# 148  04-021-0048         Hrodna           city  53.699898  23.850145       4
# 160  04-022-0117         Hrodna           city  53.656067  23.842204       4
# 169  04-022-0135         Hrodna           city  53.687918  23.859038       4
# 259  05-039-0046  Maryina Horka  town_below100  53.505014  28.136959       5
# 268  05-041-0030        Прилепы  minsk_village   54.07545  27.836825       5
# 283  05-141-0003     Borovlyany   minsk_suburb  53.997901  27.681891       5
# 293  05-141-0026         Копище   minsk_suburb  53.957011  27.663044       5
# 307  05-141-0056        Старина   minsk_suburb  53.949808  27.838055       5
# 315  05-141-0078         Hatava   minsk_suburb  53.783996  27.630903       5
# 320  05-141-0092        Sienica   minsk_suburb  53.822665  27.517239       5
# 344  06-121-0006          Вишов        village  53.983492  29.986357       6
# 359  07-001-0010          Minsk        capital  53.882396  27.691251       7
# 363  07-001-0060          Minsk        capital  53.864485  27.672629       7
# 364  07-001-0061          Minsk        capital  53.864485  27.672629       7
# 380  07-003-0024          Minsk        capital  53.876998  27.505084       7
# 385  07-004-0004          Minsk        capital  53.853912  27.549407       7
# 397  07-006-0037          Minsk        capital  53.957201   27.63119       7
#
#      monitoredVotes  registered  photoVoices  officialVotes  ...  \
# 8               NaN         191          111          911.0  ...
# 29              NaN         396          243         1919.0  ...
# 33              NaN         421          249         2152.0  ...
# 34              NaN         432          271         1940.0  ...
# 71              NaN         441          283         2079.0  ...
# 78              NaN          36           19          459.0  ...
# 113             NaN         133           59          711.0  ...
# 148             NaN         209          122         1451.0  ...
# 160             NaN         246          140         1410.0  ...
# 169             NaN         312          198         1383.0  ...
# 259             NaN         140           62         1516.0  ...
# 268             NaN         175          103          813.0  ...
# 283             NaN         510          299         1538.0  ...
# 293             NaN        1901         1440         2607.0  ...
# 307             NaN         201          125          711.0  ...
# 315             NaN         388          230         1733.0  ...
# 320             NaN         636          382         1900.0  ...
# 344             NaN          62           20         1409.0  ...
# 359             NaN         305          189         1151.0  ...
# 363             NaN         336          181         1151.0  ...
# 364             NaN         290          155         1015.0  ...
# 380             NaN         388          252         1446.0  ...
# 385             NaN         343          207         1414.0  ...
# 397             NaN         473          285         1193.0  ...
#
#      lukashenko_officialVotes  lukashenko_photoVoices  tihanovkaja_registered  \
# 8                       393.0                       1                     182
# 29                      661.0                       1                     379
# 33                     1342.0                       0                     411
# 34                      499.0                       0                     423
# 71                     1414.0                       0                     422
# 78                      383.0                       0                      33
# 113                     227.0                       0                     127
# 148                     713.0                       1                     198
# 160                     405.0                       0                     237
# 169                     411.0                       0                     303
# 259                    1092.0                       0                     133
# 268                     279.0                       0                     168
# 283                     291.0                       0                     484
# 293                     132.0                       0                    1860
# 307                     199.0                       0                     197
# 315                     711.0                       0                     377
# 320                     511.0                       1                     604
# 344                    1176.0                       0                      58
# 359                     269.0                       0                     297
# 363                     544.0                       0                     322
# 364                     489.0                       0                     276
# 380                     605.0                       0                     372
# 385                     642.0                       1                     331
# 397                     207.0                       0                     452
#
#      tihanovkaja_officialVotes  tihanovkaja_photoVoices  zubr_id  observers  \
# 8                        410.0                      109      925          2
# 29                      1055.0                      237     1003          2
# 33                       571.0                      245     1033          3
# 34                      1155.0                      267     1041          2
# 71                       504.0                      277     1891          1
# 78                        41.0                       17     2147          1
# 113                      389.0                       58     2964          1
# 148                      620.0                      118     3546          1
# 160                      819.0                      138     3615          2
# 169                      844.0                      193     3633          0
# 259                      353.0                       62     4861          4
# 268                      444.0                      101     4966          3
# 283                     1048.0                      291     4575          3
# 293                     2341.0                     1424     4598         22
# 307                      433.0                      124     4628          4
# 315                      834.0                      226     4650          5
# 320                     1128.0                      369     4664          3
# 344                      138.0                       19     5407          1
# 359                      751.0                      188      164          3
# 363                      465.0                      175      214          3
# 364                      390.0                      151      215          1
# 380                      686.0                      246      348          4
# 385                      510.0                      205      434          4
# 397                      848.0                      278      560          7
#
#      wrong-voters-number  major-violations  minor-violations
# 8                  False             False              True
# 29                 False             False             False
# 33                 False             False             False
# 34                 False             False             False
# 71                 False             False             False
# 78                 False             False             False
# 113                False             False              True
# 148                False             False              True
# 160                False             False             False
# 169                False             False             False
# 259                False             False             False
# 268                False             False              True
# 283                False             False             False
# 293                False             False             False
# 307                False             False             False
# 315                False             False             False
# 320                False             False             False
# 344                False             False              True
# 359                False             False              True
# 363                False             False              True
# 364                False             False             False
# 380                False             False              True
# 385                False             False             False
# 397                False             False              True
#
# [24 rows x 40 columns]

# %%
diff[diff != 0]
# Out:
# 8       1.0
# 29    -17.0
# 33      2.0
# 34      1.0
# 71     13.0
# 78     -2.0
# 113    -3.0
# 148     3.0
# 160     2.0
# 169    -4.0
# 259    14.0
# 268     1.0
# 283   -12.0
# 293     2.0
# 307     2.0
# 315     9.0
# 320     2.0
# 344     5.0
# 359    12.0
# 363    -5.0
# 364    -8.0
# 380     1.0
# 385   -24.0
# 397    -5.0
# dtype: float64

# %%
df.loc[diff < 0, 'officialVotes'] -= diff
df.loc[diff > 0, 'corrupted_officialVotes'] += diff

# %%
df.to_csv('trusted-for-alternative-fixed.csv', index=False)
