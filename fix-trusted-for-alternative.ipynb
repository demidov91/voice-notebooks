# %%
from decimal import Decimal
import pandas as pd

# %%
df = pd.read_csv('trusted-for-alternative.csv', converters={'latitude': Decimal, 'longitude': Decimal})

# %%
candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja', 'tihanovkaja']
alt_candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja']

# %%
df.loc[df['corrupted_officialVotes'].isna(), 'corrupted_officialVotes'] = 0

# %%
df.loc[df['id'] == '07-001-0089', 'officialVotes'] -= 42
df.loc[df['id'] == '07-006-0041', 'corrupted_officialVotes'] -= 60

# %%
diff = df['officialVotes'] - sum(df[f'{c}_officialVotes'] for c in (candidates + ['lukashenko']))

# %%
df[diff != 0]
# Out:
#               id        town           area   latitude  longitude  region  \
# 11   01-011-0049       Brest           city  52.100105  23.784281       1
# 13   01-011-0087       Brest           city   52.05665  23.737146       1
# 67   03-091-0018     Zhlobin  town_below100  52.905065  30.014088       3
# 91   04-021-0048      Hrodna           city  53.699898  23.850145       4
# 97   04-022-0117      Hrodna           city  53.656067  23.842204       4
# 101  04-022-0135      Hrodna           city  53.687918  23.859038       4
# 165  05-041-0030     Прилепы        village   54.07545  27.836825       5
# 179  05-141-0003  Borovlyany   minsk_suburb  53.997901  27.681891       5
# 194  05-141-0056     Старина   minsk_suburb  53.949808  27.838055       5
# 200  05-141-0078      Hatava   minsk_suburb  53.783996  27.630903       5
# 205  05-141-0092     Sienica   minsk_suburb  53.822665  27.517239       5
# 216  06-012-0069    Babruysk   town_over100  53.170629  29.198975       6
# 233  07-001-0010       Minsk        capital  53.882396  27.691251       7
# 237  07-001-0060       Minsk        capital  53.864485  27.672629       7
# 254  07-003-0024       Minsk        capital  53.876998  27.505084       7
# 259  07-004-0004       Minsk        capital  53.853912  27.549407       7
# 272  07-006-0037       Minsk        capital  53.957201   27.63119       7
#
#      monitoredVotes  registered  photoVoices  officialVotes  ...  \
# 11              NaN         396          243         1919.0  ...
# 13              NaN         432          271         1940.0  ...
# 67              NaN         133           59          711.0  ...
# 91              NaN         209          122         1451.0  ...
# 97              NaN         246          140         1410.0  ...
# 101             NaN         312          198         1383.0  ...
# 165             NaN         175          103          813.0  ...
# 179             NaN         510          299         1538.0  ...
# 194             NaN         201          125          711.0  ...
# 200             NaN         388          230         1733.0  ...
# 205             NaN         636          382         1900.0  ...
# 216             NaN         149           77         1448.0  ...
# 233             NaN         305          189         1151.0  ...
# 237             NaN         336          181         1151.0  ...
# 254             NaN         388          252         1446.0  ...
# 259             NaN         343          207         1414.0  ...
# 272             NaN         473          285         1193.0  ...
#
#      lukashenko_officialVotes  lukashenko_photoVoices  tihanovkaja_registered  \
# 11                      661.0                       1                     379
# 13                      499.0                       0                     423
# 67                      227.0                       0                     127
# 91                      713.0                       1                     198
# 97                      405.0                       0                     237
# 101                     411.0                       0                     303
# 165                     279.0                       0                     168
# 179                     291.0                       0                     484
# 194                     199.0                       0                     197
# 200                     711.0                       0                     377
# 205                     511.0                       1                     604
# 216                     879.0                       0                     143
# 233                     269.0                       0                     297
# 237                     544.0                       0                     322
# 254                     605.0                       0                     372
# 259                     642.0                       1                     331
# 272                     207.0                       0                     452
#
#      tihanovkaja_officialVotes  tihanovkaja_photoVoices  zubr_id  observers  \
# 11                      1055.0                      237     1003          2
# 13                      1155.0                      267     1041          2
# 67                       389.0                       58     2964          1
# 91                       620.0                      118     3546          1
# 97                       819.0                      138     3615          2
# 101                      844.0                      193     3633          0
# 165                      444.0                      101     4966          3
# 179                     1048.0                      291     4575          3
# 194                      433.0                      124     4628          4
# 200                      834.0                      226     4650          5
# 205                     1128.0                      369     4664          3
# 216                      301.0                       74     5215          0
# 233                      751.0                      188      164          3
# 237                      465.0                      175      214          3
# 254                      686.0                      246      348          4
# 259                      510.0                      205      434          4
# 272                      848.0                      278      560          7
#
#      wrong-voters-number  major-violations  minor-violations
# 11                 False             False             False
# 13                 False             False             False
# 67                 False             False              True
# 91                 False             False              True
# 97                 False             False             False
# 101                False             False             False
# 165                False             False              True
# 179                False             False             False
# 194                False             False             False
# 200                False             False             False
# 205                False             False             False
# 216                False             False             False
# 233                False             False              True
# 237                False             False              True
# 254                False             False              True
# 259                False             False             False
# 272                False             False              True
#
# [17 rows x 40 columns]

# %%
diff[diff != 0]
# Out:
# 11    -17.0
# 13      1.0
# 67     -3.0
# 91      3.0
# 97      2.0
# 101    -4.0
# 165     1.0
# 179   -12.0
# 194     2.0
# 200     9.0
# 205     2.0
# 216     6.0
# 233    12.0
# 237    -5.0
# 254     1.0
# 259   -24.0
# 272    -5.0
# dtype: float64

# %%
df.loc[diff < 0, 'officialVotes'] -= diff
df.loc[diff > 0, 'corrupted_officialVotes'] += diff

# %%
df.to_csv('trusted-for-alternative-fixed.csv', index=False)
