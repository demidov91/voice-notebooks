# %%
from decimal import Decimal
import pandas as pd

# %%
df = pd.read_csv('trusted-for-alternative.csv', converters={'latitude': Decimal, 'longitude': Decimal})

# %%
candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja', 'tihanovkaja']
alt_candidates = ['against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja']

# %%
df.loc[df['corrupted_officialVotes'].isna(), 'corrupted_officialVotes'] = 0

# %%
df.loc[df['id'] == '07-001-0089', 'officialVotes'] -= 42
df.loc[df['id'] == '07-006-0041', 'corrupted_officialVotes'] -= 60

# %%
diff = df['officialVotes'] - sum(df[f'{c}_officialVotes'] for c in (candidates + ['lukashenko']))

# %%
df[diff != 0]
# Out:
#               id        town           area   latitude  longitude  region  \
# 14   01-011-0049       Brest           city  52.100105  23.784281       1
# 16   01-011-0079       Brest           city  52.067807  23.729286       1
# 17   01-011-0087       Brest           city   52.05665  23.737146       1
# 49   02-071-0015   Домжерицы        village  54.747319   28.31541       2
# 74   03-091-0018     Zhlobin  town_below100  52.905065  30.014088       3
# 100  04-021-0048      Hrodna           city  53.699898  23.850145       4
# 108  04-022-0117      Hrodna           city  53.656067  23.842204       4
# 114  04-022-0135      Hrodna           city  53.687918  23.859038       4
# 179  05-041-0030     Прилепы        village   54.07545  27.836825       5
# 192  05-141-0003  Borovlyany   minsk_suburb  53.997901  27.681891       5
# 211  05-141-0056     Старина   minsk_suburb  53.949808  27.838055       5
# 217  05-141-0078      Hatava   minsk_suburb  53.783996  27.630903       5
# 222  05-141-0092     Sienica   minsk_suburb  53.822665  27.517239       5
# 251  07-001-0010       Minsk        capital  53.882396  27.691251       7
# 255  07-001-0060       Minsk        capital  53.864485  27.672629       7
# 272  07-003-0024       Minsk        capital  53.876998  27.505084       7
# 277  07-004-0004       Minsk        capital  53.853912  27.549407       7
# 289  07-006-0037       Minsk        capital  53.957201   27.63119       7
#
#      monitoredVotes  registered  photoVoices  officialVotes  ...  \
# 14              NaN         396          243         1919.0  ...
# 16              NaN         421          249         2152.0  ...
# 17              NaN         432          271         1940.0  ...
# 49              NaN          36           19          459.0  ...
# 74              NaN         133           59          711.0  ...
# 100             NaN         209          122         1451.0  ...
# 108             NaN         246          140         1410.0  ...
# 114             NaN         312          198         1383.0  ...
# 179             NaN         175          103          813.0  ...
# 192             NaN         510          299         1538.0  ...
# 211             NaN         201          125          711.0  ...
# 217             NaN         388          230         1733.0  ...
# 222             NaN         636          382         1900.0  ...
# 251             NaN         305          189         1151.0  ...
# 255             NaN         336          181         1151.0  ...
# 272             NaN         388          252         1446.0  ...
# 277             NaN         343          207         1414.0  ...
# 289             NaN         473          285         1193.0  ...
#
#      lukashenko_officialVotes  lukashenko_photoVoices  tihanovkaja_registered  \
# 14                      661.0                       1                     379
# 16                     1342.0                       0                     411
# 17                      499.0                       0                     423
# 49                      383.0                       0                      33
# 74                      227.0                       0                     127
# 100                     713.0                       1                     198
# 108                     405.0                       0                     237
# 114                     411.0                       0                     303
# 179                     279.0                       0                     168
# 192                     291.0                       0                     484
# 211                     199.0                       0                     197
# 217                     711.0                       0                     377
# 222                     511.0                       1                     604
# 251                     269.0                       0                     297
# 255                     544.0                       0                     322
# 272                     605.0                       0                     372
# 277                     642.0                       1                     331
# 289                     207.0                       0                     452
#
#      tihanovkaja_officialVotes  tihanovkaja_photoVoices  zubr_id  observers  \
# 14                      1055.0                      237     1003          2
# 16                       571.0                      245     1033          3
# 17                      1155.0                      267     1041          2
# 49                        41.0                       17     2147          1
# 74                       389.0                       58     2964          1
# 100                      620.0                      118     3546          1
# 108                      819.0                      138     3615          2
# 114                      844.0                      193     3633          0
# 179                      444.0                      101     4966          3
# 192                     1048.0                      291     4575          3
# 211                      433.0                      124     4628          4
# 217                      834.0                      226     4650          5
# 222                     1128.0                      369     4664          3
# 251                      751.0                      188      164          3
# 255                      465.0                      175      214          3
# 272                      686.0                      246      348          4
# 277                      510.0                      205      434          4
# 289                      848.0                      278      560          7
#
#      wrong-voters-number  major-violations  minor-violations
# 14                 False             False             False
# 16                 False             False             False
# 17                 False             False             False
# 49                 False             False             False
# 74                 False             False              True
# 100                False             False              True
# 108                False             False             False
# 114                False             False             False
# 179                False             False              True
# 192                False             False             False
# 211                False             False             False
# 217                False             False             False
# 222                False             False             False
# 251                False             False              True
# 255                False             False              True
# 272                False             False              True
# 277                False             False             False
# 289                False             False              True
#
# [18 rows x 40 columns]

# %%
diff[diff != 0]
# Out:
# 14    -17.0
# 16      2.0
# 17      1.0
# 49     -2.0
# 74     -3.0
# 100     3.0
# 108     2.0
# 114    -4.0
# 179     1.0
# 192   -12.0
# 211     2.0
# 217     9.0
# 222     2.0
# 251    12.0
# 255    -5.0
# 272     1.0
# 277   -24.0
# 289    -5.0
# dtype: float64

# %%
df.loc[diff < 0, 'officialVotes'] -= diff
df.loc[diff > 0, 'corrupted_officialVotes'] += diff

# %%
df.to_csv('trusted-for-alternative-fixed.csv', index=False)
