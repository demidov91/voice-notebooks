# %%
import pandas as pd
import numpy as np
from decimal import Decimal

# %%
df = pd.read_csv('trusted-for-alternative.csv', converters={'latitude': Decimal, 'longitude': Decimal})

# %%
areas = ['city', 'suburb', 'capital', 'village', 'town_below100', 'town_over100', 'embassy']

# %%
coefficients = []

for area in areas:
    mask = df['area'] == area
    
    data = df[mask]
    slope, _, _, _ = np.linalg.lstsq(
        np.array(data['tihanovkaja_photoVoices'])[:,np.newaxis], data['tihanovkaja_officialVotes'], None
    )
    slope = slope[0]
    
    
    mask = mask & ~df['tihanovkaja_officialVotes'].isna() & data['tihanovkaja_photoVoices'] > 0
    data = df[mask]
    
    more_than_expected = data[data['tihanovkaja_officialVotes'] / data['tihanovkaja_photoVoices'] > slope]
    less_than_expected = data[data['tihanovkaja_officialVotes'] / data['tihanovkaja_photoVoices'] < slope]
    
    more_coefficients = more_than_expected['tihanovkaja_officialVotes'] / more_than_expected['tihanovkaja_photoVoices'] / slope
    less_coefficients = less_than_expected['tihanovkaja_officialVotes'] / less_than_expected['tihanovkaja_photoVoices'] / slope

    more_mean = np.mean(more_coefficients)
    less_mean = np.mean(less_coefficients)
    more_std = np.std(more_coefficients)
    less_std = np.std(less_coefficients)
    

    coefficients.append({
        'area': area,
        'coefficient': slope, 
        'more_mean': more_mean,
        'less_mean': less_mean,
        'more_std': more_std,
        'less_std': less_std,        
    })
    

coef_df = pd.DataFrame(coefficients)

# %%
coef_df
# Out:
#             area  coefficient  more_mean  less_mean  more_std  less_std
# 0           city     2.576210   1.535174   0.641745  0.494907  0.173411
# 1         suburb     2.232375   1.943564   0.831990  1.666507  0.093624
# 2        capital     1.916785   1.447489   0.731796  0.787438  0.141557
# 3        village     3.305239   2.894109   0.769916  1.665011  0.199267
# 4  town_below100     3.634188   1.530651   0.649515  0.391596  0.209391
# 5   town_over100     3.166660   1.608945   0.579178  0.642697  0.193359
# 6        embassy    13.706030   4.160290        NaN  0.813019       NaN

# %%
coef_df.to_csv('tihanovkaja_photo_coefficients.csv', float_format='%.3f', index=False)

# %%
def _real_tihanovkaja_coeff_for_df(data, candidate):
    return data[f'{candidate}_officialVotes'] / data['tihanovkaja_officialVotes']
    

def build_coeff_for_candidate(candidate):
    coefficients = []

    for area in areas:
        mask = (df['area'] == area) & ~df[f'{candidate}_officialVotes'].isna() 
        
        if candidate in ('against', 'corrupted'):
            mask &= (df['corrupted_officialVotes'] > 0)

        data = df[mask]
        slope, _, _, _ = np.linalg.lstsq(
            np.array(data['tihanovkaja_officialVotes'])[:,np.newaxis], data[f'{candidate}_officialVotes'], None
        )
        slope = slope[0]


        mask = (
            mask & 
            (df[f'tihanovkaja_officialVotes'] > 0) & 
            ~df[f'{candidate}_officialVotes'].isna()
        )
        data = df[mask]
        
        real_coefficients = _real_tihanovkaja_coeff_for_df(data, candidate)

        more_than_expected = data[real_coefficients > slope]
        less_than_expected = data[real_coefficients < slope]

        more_coefficients = _real_tihanovkaja_coeff_for_df(more_than_expected, candidate) / slope
        less_coefficients = _real_tihanovkaja_coeff_for_df(less_than_expected, candidate) / slope

        more_mean = np.mean(more_coefficients)
        less_mean = np.mean(less_coefficients)
        more_std = np.std(more_coefficients)
        less_std = np.std(less_coefficients)


        yield {
            'candidate': candidate,
            'area': area,            
            'tih_coefficient': slope, 
            'more_mean': more_mean,
            'less_mean': less_mean,
            'more_std': more_std,
            'less_std': less_std,        
        }

# %%
candidates = (
    'against', 'cherechen', 'corrupted', 'dmitriyev', 'kanopatskaja',
)

# %%
alternative = []

for candidate in candidates:
    alternative.extend(build_coeff_for_candidate(candidate))

# %%
alternative
# Out:
# [{'candidate': 'against',
#   'area': 'city',
#   'tih_coefficient': 0.15143736786430997,
#   'more_mean': 2.7866152736175445,
#   'less_mean': 0.6389896327010721,
#   'more_std': 2.175298317802411,
#   'less_std': 0.2704438222873623},
#  {'candidate': 'against',
#   'area': 'suburb',
#   'tih_coefficient': 0.07691446151068852,
#   'more_mean': 1.5134073994895878,
#   'less_mean': 0.6733633531290247,
#   'more_std': 0.39894179075214425,
#   'less_std': 0.2091543482940307},
#  {'candidate': 'against',
#   'area': 'capital',
#   'tih_coefficient': 0.14604847411496116,
#   'more_mean': 2.2557738895954698,
#   'less_mean': 0.5426448774025191,
#   'more_std': 1.091608377213615,
#   'less_std': 0.2616324796143272},
#  {'candidate': 'against',
#   'area': 'village',
#   'tih_coefficient': 0.12675562256377343,
#   'more_mean': 2.153784790738719,
#   'less_mean': 0.6337928286327533,
#   'more_std': 1.459974260944058,
#   'less_std': 0.2343897164441303},
#  {'candidate': 'against',
#   'area': 'town_below100',
#   'tih_coefficient': 0.14895798335369984,
#   'more_mean': 2.652120718505526,
#   'less_mean': 0.6216088956546919,
#   'more_std': 1.9882804630060535,
#   'less_std': 0.24884312824082283},
#  {'candidate': 'against',
#   'area': 'town_over100',
#   'tih_coefficient': 0.16469478920639719,
#   'more_mean': 2.6280490056666146,
#   'less_mean': 0.6653466166836216,
#   'more_std': 1.6600704991138033,
#   'less_std': 0.20248783618563693},
#  {'candidate': 'against',
#   'area': 'embassy',
#   'tih_coefficient': 0.01315012718872136,
#   'more_mean': 1.5254164631618,
#   'less_mean': 0.6356869872686963,
#   'more_std': 0.5527487055979926,
#   'less_std': 0.30695923692909904},
#  {'candidate': 'cherechen',
#   'area': 'city',
#   'tih_coefficient': 0.039770330427182116,
#   'more_mean': 2.167747942194027,
#   'less_mean': 0.6071748051190622,
#   'more_std': 1.3113268711030408,
#   'less_std': 0.2593828108212038},
#  {'candidate': 'cherechen',
#   'area': 'suburb',
#   'tih_coefficient': 0.020375922281166754,
#   'more_mean': 2.049112565745308,
#   'less_mean': 0.6051358121736835,
#   'more_std': 1.783595931017639,
#   'less_std': 0.2168394294102098},
#  {'candidate': 'cherechen',
#   'area': 'capital',
#   'tih_coefficient': 0.03452203574403001,
#   'more_mean': 2.6403621265036348,
#   'less_mean': 0.6814487139697287,
#   'more_std': 2.211119751498084,
#   'less_std': 0.1954731179346741},
#  {'candidate': 'cherechen',
#   'area': 'village',
#   'tih_coefficient': 0.03924811421526943,
#   'more_mean': 2.212586592970142,
#   'less_mean': 0.5864240680810089,
#   'more_std': 1.5529133707301799,
#   'less_std': 0.20827294588708123},
#  {'candidate': 'cherechen',
#   'area': 'town_below100',
#   'tih_coefficient': 0.04051110123576947,
#   'more_mean': 2.045538037314628,
#   'less_mean': 0.6349415115496134,
#   'more_std': 1.2736784110331858,
#   'less_std': 0.2566929076329336},
#  {'candidate': 'cherechen',
#   'area': 'town_over100',
#   'tih_coefficient': 0.049435014289260955,
#   'more_mean': 1.9551613651598503,
#   'less_mean': 0.6937329191479075,
#   'more_std': 1.0631272464275923,
#   'less_std': 0.22972082458561877},
#  {'candidate': 'cherechen',
#   'area': 'embassy',
#   'tih_coefficient': 0.003971235892033951,
#   'more_mean': 1.940823556266207,
#   'less_mean': 0.6300168983833087,
#   'more_std': 0.6772758559042072,
#   'less_std': 0.25294126963332947},
#  {'candidate': 'corrupted',
#   'area': 'city',
#   'tih_coefficient': 0.019590435588884424,
#   'more_mean': 3.284559417858999,
#   'less_mean': 0.6028156694256285,
#   'more_std': 2.8837640326669405,
#   'less_std': 0.24690231475201793},
#  {'candidate': 'corrupted',
#   'area': 'suburb',
#   'tih_coefficient': 0.014563168504505586,
#   'more_mean': 1.992133870049723,
#   'less_mean': 0.713925498116563,
#   'more_std': 0.6640791503106467,
#   'less_std': 0.22175215358166073},
#  {'candidate': 'corrupted',
#   'area': 'capital',
#   'tih_coefficient': 0.038603864677941364,
#   'more_mean': 3.5363592527585,
#   'less_mean': 0.38605829584220164,
#   'more_std': 2.3174220875948466,
#   'less_std': 0.24443630910615624},
#  {'candidate': 'corrupted',
#   'area': 'village',
#   'tih_coefficient': 0.029123695470041306,
#   'more_mean': 2.774295332151271,
#   'less_mean': 0.5940011961331311,
#   'more_std': 1.9908271099097838,
#   'less_std': 0.2419410699204031},
#  {'candidate': 'corrupted',
#   'area': 'town_below100',
#   'tih_coefficient': 0.02214106401928412,
#   'more_mean': 3.250086223892239,
#   'less_mean': 0.6293209757495235,
#   'more_std': 5.530214222132578,
#   'less_std': 0.24460327923188455},
#  {'candidate': 'corrupted',
#   'area': 'town_over100',
#   'tih_coefficient': 0.0377809796409847,
#   'more_mean': 2.6787062019644456,
#   'less_mean': 0.5142205682143823,
#   'more_std': 2.06370418390718,
#   'less_std': 0.20200561589895571},
#  {'candidate': 'corrupted',
#   'area': 'embassy',
#   'tih_coefficient': 0.011921625049132668,
#   'more_mean': 2.259533414274948,
#   'less_mean': 0.42237249425039514,
#   'more_std': 0.2477845247337751,
#   'less_std': 0.28406301385746235},
#  {'candidate': 'dmitriyev',
#   'area': 'city',
#   'tih_coefficient': 0.042411319911014995,
#   'more_mean': 2.0076492143938243,
#   'less_mean': 0.6642897017698387,
#   'more_std': 0.9637735949790417,
#   'less_std': 0.2547826719465992},
#  {'candidate': 'dmitriyev',
#   'area': 'suburb',
#   'tih_coefficient': 0.025273764217494638,
#   'more_mean': 1.990469721977278,
#   'less_mean': 0.662977181828201,
#   'more_std': 1.2433945032216591,
#   'less_std': 0.22618951221688569},
#  {'candidate': 'dmitriyev',
#   'area': 'capital',
#   'tih_coefficient': 0.038084005618804956,
#   'more_mean': 2.120071965935494,
#   'less_mean': 0.7000846040783035,
#   'more_std': 1.2442456929849615,
#   'less_std': 0.19760703050139075},
#  {'candidate': 'dmitriyev',
#   'area': 'village',
#   'tih_coefficient': 0.050052423777588714,
#   'more_mean': 2.023754091148463,
#   'less_mean': 0.6412248777807947,
#   'more_std': 1.2705154359754252,
#   'less_std': 0.2362958872137488},
#  {'candidate': 'dmitriyev',
#   'area': 'town_below100',
#   'tih_coefficient': 0.04600768866767707,
#   'more_mean': 2.034925608174686,
#   'less_mean': 0.6888100588294006,
#   'more_std': 1.3475426542725006,
#   'less_std': 0.25026717033082163},
#  {'candidate': 'dmitriyev',
#   'area': 'town_over100',
#   'tih_coefficient': 0.050176883145719525,
#   'more_mean': 2.031894940525396,
#   'less_mean': 0.7126748619834252,
#   'more_std': 1.3061180925349491,
#   'less_std': 0.20808784728247245},
#  {'candidate': 'dmitriyev',
#   'area': 'embassy',
#   'tih_coefficient': 0.00815902810878478,
#   'more_mean': 2.755408194097741,
#   'less_mean': 0.6518481115157057,
#   'more_std': 0.7229486559439641,
#   'less_std': 0.20357670564267574},
#  {'candidate': 'kanopatskaja',
#   'area': 'city',
#   'tih_coefficient': 0.03263598790749443,
#   'more_mean': 3.220895775229643,
#   'less_mean': 0.6444402758435918,
#   'more_std': 3.0791785874509188,
#   'less_std': 0.20117210482307615},
#  {'candidate': 'kanopatskaja',
#   'area': 'suburb',
#   'tih_coefficient': 0.01707594494391412,
#   'more_mean': 2.287501505902296,
#   'less_mean': 0.7618604140803046,
#   'more_std': 1.8582724955493974,
#   'less_std': 0.20764767362661193},
#  {'candidate': 'kanopatskaja',
#   'area': 'capital',
#   'tih_coefficient': 0.04217855058512373,
#   'more_mean': 3.1358859293928227,
#   'less_mean': 0.5753197827213736,
#   'more_std': 2.1516555195639135,
#   'less_std': 0.21595921343808516},
#  {'candidate': 'kanopatskaja',
#   'area': 'village',
#   'tih_coefficient': 0.043487517227925994,
#   'more_mean': 2.630090720568579,
#   'less_mean': 0.6470252653871815,
#   'more_std': 1.977585393213307,
#   'less_std': 0.2193710510586713},
#  {'candidate': 'kanopatskaja',
#   'area': 'town_below100',
#   'tih_coefficient': 0.03042444937029869,
#   'more_mean': 3.0849837898182355,
#   'less_mean': 0.65442328233629,
#   'more_std': 3.0508032713749595,
#   'less_std': 0.2176774933800152},
#  {'candidate': 'kanopatskaja',
#   'area': 'town_over100',
#   'tih_coefficient': 0.036510543369783266,
#   'more_mean': 2.968097733602192,
#   'less_mean': 0.5951716604836331,
#   'more_std': 2.553117138003809,
#   'less_std': 0.23521617389252703},
#  {'candidate': 'kanopatskaja',
#   'area': 'embassy',
#   'tih_coefficient': 0.007569293783250304,
#   'more_mean': 1.9009692458503566,
#   'less_mean': 0.31134570210967044,
#   'more_std': 0.5812816944943885,
#   'less_std': 0.030901111552992116}]

# %%
[x for x in alternative if (x['less_mean'] + x['less_std']) > 1]
# Out:
# []

# %%
[x for x in alternative if x['tih_coefficient'] >  x['more_mean'] - x['more_std']]
# Out:
# [{'candidate': 'corrupted',
#   'area': 'town_below100',
#   'tih_coefficient': 0.02214106401928412,
#   'more_mean': 3.250086223892239,
#   'less_mean': 0.6293209757495235,
#   'more_std': 5.530214222132578,
#   'less_std': 0.24460327923188455}]

# %%
pd.DataFrame(alternative).to_csv('alternative_coefficients.csv', float_format='%.4f', index=False)
